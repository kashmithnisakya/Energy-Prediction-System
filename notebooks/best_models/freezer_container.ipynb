# %%
import os
from pathlib import Path
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, TimeDistributed, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# Out:
# 2025-04-30 12:35:37.034707: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
csv_path = "/Users/kashmithnisakya/Developer/Data_Science/Energy-Prediction-System/ml/data/processed/freezer_container_data_2025_03_04_09_35_56.csv"
model_name = "freezer_container"
features = ["energy"]
input_window = 3360
output_window = 3360
batch_size = 32
epochs = 50
hidden_size = 64
learning_rate = 0.001

# %%
def preprocess(csv_path, features, input_window, output_window):
    df = pd.read_csv(csv_path, parse_dates=["time"])
    df = df.sort_values("time").set_index("time")[features]

    # Store original energy for comparison
    original_energy = df["energy"].copy()

    # Handle zero values
    energy = df["energy"].copy()
    mask = energy == 0
    first_nonzero_idx = energy.ne(0).idxmax()
    mask.loc[:first_nonzero_idx] = False
    energy.loc[mask] = np.nan
    energy = energy.ffill()
    df["energy"] = energy
    df = df.ffill()

    # Plotting the original and filtered energy values
    plt.figure(figsize=(12, 6))
    plt.plot(
        df.index, original_energy, label="Original Energy", alpha=0.5, linestyle="--"
    )
    plt.plot(df.index, df["energy"], label="Filtered Energy", alpha=0.5)
    plt.title("Original vs Filtered Energy Values")
    plt.xlabel("Time")
    plt.ylabel("Energy Value")
    plt.legend()
    plt.grid(True)
    plt.show()

    scaler = MinMaxScaler()
    scaled = scaler.fit_transform(df)

    X, y = [], []
    for i in range(len(scaled) - input_window - output_window):
        X.append(scaled[i : i + input_window])
        y.append(scaled[i + input_window : i + input_window + output_window])

    X = np.array(X)
    y = np.array(y)
    print(f"✅ X shape: {X.shape}, y shape: {y.shape}")
    return X, y, scaler, df

# %%
X, y, scaler, df_full = preprocess(csv_path, features, input_window, output_window)
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
# Out:
# ✅ X shape: (123280, 3360, 1), y shape: (123280, 3360, 1)

# %%
def build_model(input_shape, hidden_size, learning_rate):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(LSTM(hidden_size, return_sequences=True))
    model.add(Dropout(0.1))
    model.add(TimeDistributed(Dense(1, activation="relu")))
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="mse",
        metrics=["mae", "mse"],
    )
    return model

# %%
model = build_model(
    input_shape=(input_window, 1), hidden_size=hidden_size, learning_rate=learning_rate
)
# Out:
# 2025-04-30 12:35:40.860558: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-30 12:35:40.860660: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-04-30 12:35:41.118520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-30 12:35:41.119223: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-30 12:35:41.119682: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 3360, 64)          16896
#
#  dropout (Dropout)           (None, 3360, 64)          0
#
#  time_distributed (TimeDistr  (None, 3360, 1)          65
#  ibuted)
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)

# %%
reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5)

# %%
ckpt = ModelCheckpoint(f"{model_name}.h5", monitor="val_loss", save_best_only=True)

# %%
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stop, reduce_lr, ckpt],
    verbose=1,
)
# Out:
# Epoch 1/50
# 2025-04-30 12:35:46.143738: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-30 12:35:46.145703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-30 12:35:46.146313: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-04-30 12:35:46.464307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-30 12:35:46.464974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-30 12:35:46.465608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-04-30 12:35:46.757984: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-04-30 12:35:46.840798: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp_10.
# 2025-04-30 12:35:46.949736: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-04-30 12:35:47.230199: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 3082/3082 [==============================] - ETA: 0s - loss: 6.3555e-04 - mae: 0.0138 - mse: 6.3555e-04
# 2025-04-30 12:45:44.898037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-30 12:45:44.898819: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-30 12:45:44.899625: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-04-30 12:45:44.936135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-04-30 12:45:45.001012: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 3082/3082 [==============================] - 642s 208ms/step - loss: 6.3555e-04 - mae: 0.0138 - mse: 6.3555e-04 - val_loss: 2.3904e-04 - val_mae: 0.0108 - val_mse: 2.3904e-04 - lr: 0.0010
# Epoch 2/50
# 3082/3082 [==============================] - 665s 216ms/step - loss: 1.3368e-04 - mae: 0.0076 - mse: 1.3368e-04 - val_loss: 3.7737e-05 - val_mae: 0.0023 - val_mse: 3.7737e-05 - lr: 0.0010
# Epoch 3/50
# 3082/3082 [==============================] - 649s 211ms/step - loss: 9.1029e-05 - mae: 0.0065 - mse: 9.1029e-05 - val_loss: 8.0703e-05 - val_mae: 0.0086 - val_mse: 8.0703e-05 - lr: 0.0010
# Epoch 4/50
# 3082/3082 [==============================] - 588s 191ms/step - loss: 8.3230e-05 - mae: 0.0064 - mse: 8.3229e-05 - val_loss: 1.2608e-06 - val_mae: 9.1027e-04 - val_mse: 1.2608e-06 - lr: 0.0010
# Epoch 5/50
# 3082/3082 [==============================] - 613s 199ms/step - loss: 8.2326e-05 - mae: 0.0063 - mse: 8.2326e-05 - val_loss: 3.2304e-05 - val_mae: 0.0055 - val_mse: 3.2304e-05 - lr: 0.0010
# Epoch 6/50
# 3082/3082 [==============================] - 628s 204ms/step - loss: 8.2057e-05 - mae: 0.0063 - mse: 8.2057e-05 - val_loss: 4.9658e-05 - val_mae: 0.0069 - val_mse: 4.9658e-05 - lr: 0.0010
# Epoch 7/50
# 3082/3082 [==============================] - 638s 207ms/step - loss: 8.2028e-05 - mae: 0.0063 - mse: 8.2028e-05 - val_loss: 7.0091e-05 - val_mae: 0.0082 - val_mse: 7.0091e-05 - lr: 0.0010
# Epoch 8/50
# 3082/3082 [==============================] - 633s 206ms/step - loss: 8.1204e-05 - mae: 0.0063 - mse: 8.1204e-05 - val_loss: 6.2474e-05 - val_mae: 0.0078 - val_mse: 6.2474e-05 - lr: 5.0000e-04
# Epoch 9/50
# 3082/3082 [==============================] - 655s 213ms/step - loss: 8.1186e-05 - mae: 0.0063 - mse: 8.1186e-05 - val_loss: 3.1708e-05 - val_mae: 0.0055 - val_mse: 3.1708e-05 - lr: 5.0000e-04

# %%
model.save("china_mill_seq2seq_3360.h5")

# %%
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.title("Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.grid(True)
plt.legend()
plt.show()

# %%
sample_input = X_test[0:1]  # Shape (1, 3360, 1)
prediction = model.predict(sample_input)  # Shape (1, 3360, 1)
# Out:
# 2025-04-30 14:10:58.724177: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2025-04-30 14:10:58.725352: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2025-04-30 14:10:58.725845: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2025-04-30 14:10:58.750950: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 578ms/step
# 2025-04-30 14:10:58.956411: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
# Inverse transform both y_test and prediction
true_future = scaler.inverse_transform(y_test[0])
predicted_future = scaler.inverse_transform(prediction[0])

# %%
# Get timestamps for plotting
start_time = df_full.index[-(output_window + 1)]
time_index = pd.date_range(
    start=start_time + pd.Timedelta(minutes=4), periods=output_window, freq="5min"
)

# %%
# Plot
plt.figure(figsize=(14, 6))
plt.plot(time_index, true_future, label="Actual Energy", color="blue")
plt.plot(
    time_index,
    predicted_future,
    label="Predicted Energy",
    linestyle="--",
    color="orange",
)
plt.title("Energy Forecast - Next 3360 Points")
plt.xlabel("Time")
plt.ylabel("Energy")
plt.grid(True)
plt.legend()
plt.show()
